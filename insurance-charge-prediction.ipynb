# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression

import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\Vmuha\OneDrive\Masaüstü\insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   str
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   str
#  5   region    1338 non-null   str
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), str(3)
# memory usage: 94.5 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
labelencoder = LabelEncoder()

# %%
df["smoker"] = labelencoder.fit_transform(df["smoker"])
df["sex"] = labelencoder.fit_transform(df["sex"])
df["region"] = labelencoder.fit_transform(df["region"])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
df["smoker"] = df["smoker"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   int64
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %%
X = df.drop("charges",axis=1)
y = df["charges"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=28)

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
regression = LinearRegression()

# %%
regression.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test_scaled)

# %%
print(f"MAE : {mean_absolute_error(y_test, y_pred):.2f}")
print(f"MSE : {mean_squared_error(y_test, y_pred):.2f}")
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# MAE : 4228.90
# MSE : 38832434.14
# r2 score : 0.71

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)

# %%
X_train_poly = poly.fit_transform(X_train_scaled)
X_test_poly = poly.transform(X_test_scaled)

# %%
regression.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test_poly)

# %%
print(f"MAE : {mean_absolute_error(y_test, y_pred):.2f}")
print(f"MSE : {mean_squared_error(y_test, y_pred):.2f}")
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# MAE : 3059.76
# MSE : 25075599.68
# r2 score : 0.82

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train_scaled, y_train)
# Out:
# Lasso()

# %%
y_pred = lasso.predict(X_test_scaled)
print(f"MAE : {mean_absolute_error(y_test, y_pred):.2f}")
print(f"MSE : {mean_squared_error(y_test, y_pred):.2f}")
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# MAE : 4228.60
# MSE : 38829185.86
# r2 score : 0.71

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train_scaled, y_train)
# Out:
# Ridge()

# %%
y_pred = ridge.predict(X_test_scaled)
print(f"MAE : {mean_absolute_error(y_test, y_pred):.2f}")
print(f"MSE : {mean_squared_error(y_test, y_pred):.2f}")
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# MAE : 4229.65
# MSE : 38809351.31
# r2 score : 0.71

# %%
from sklearn.linear_model import ElasticNet
elasticnet = ElasticNet()
elasticnet.fit(X_train_scaled, y_train)
# Out:
# ElasticNet()

# %%
y_pred = elasticnet.predict(X_test_scaled)
print(f"MAE : {mean_absolute_error(y_test, y_pred):.2f}")
print(f"MSE : {mean_squared_error(y_test, y_pred):.2f}")
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# MAE : 4951.51
# MSE : 44604931.65
# r2 score : 0.67

# %%
from sklearn.linear_model import LassoCV
lassocv = LassoCV(cv=5)
lassocv.fit(X_train_scaled, y_train)
y_pred = lassocv.predict(X_test_scaled)
print(f"Best Alpha: {lassocv.alpha_:.4f}")
print(f"MAE : {mean_absolute_error(y_test, y_pred):.2f}")
print(f"MSE : {mean_squared_error(y_test, y_pred):.2f}")
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# Best Alpha: 9.7749
# MAE : 4226.02
# MSE : 38801264.30
# r2 score : 0.71

# %%
from sklearn.linear_model import RidgeCV
ridgecv = RidgeCV(cv=5)
ridgecv.fit(X_train_scaled, y_train)
y_pred = ridgecv.predict(X_test_scaled)
print(f"Best Alpha: {ridgecv.alpha_:.4f}")
print(f"MAE : {mean_absolute_error(y_test, y_pred):.2f}")
print(f"MSE : {mean_squared_error(y_test, y_pred):.2f}")
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# Best Alpha: 1.0000
# MAE : 4229.65
# MSE : 38809351.31
# r2 score : 0.71

# %%
from sklearn.linear_model import ElasticNetCV
elasticnetcv = ElasticNetCV(cv=5)
elasticnetcv.fit(X_train_scaled, y_train)
y_pred = elasticnetcv.predict(X_test_scaled)
print(f"Best Alpha: {elasticnetcv.alpha_:.4f}")
print(f"Best l1_ratio: {elasticnetcv.l1_ratio_:.4f}")
print(f"MAE : {mean_absolute_error(y_test, y_pred):.2f}")
print(f"MSE : {mean_squared_error(y_test, y_pred):.2f}")
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# Best Alpha: 19.5498
# Best l1_ratio: 0.5000
# MAE : 8152.56
# MSE : 116822452.12
# r2 score : 0.14

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train_scaled, y_train)
y_pred = svr.predict(X_test_scaled)
print(f"MAE : {mean_absolute_error(y_test, y_pred):.2f}")
print(f"MSE : {mean_squared_error(y_test, y_pred):.2f}")
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# MAE : 8277.96
# MSE : 150481221.08
# r2 score : -0.11

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train_scaled, y_train)
y_pred = knn.predict(X_test_scaled)
print(f"MAE : {mean_absolute_error(y_test, y_pred):.2f}")
print(f"MSE : {mean_squared_error(y_test, y_pred):.2f}")
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# MAE : 3250.69
# MSE : 31278207.77
# r2 score : 0.77

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(random_state=28)
dt.fit(X_train_scaled, y_train)
y_pred = dt.predict(X_test_scaled)
print(f"MAE : {mean_absolute_error(y_test, y_pred):.2f}")
print(f"MSE : {mean_squared_error(y_test, y_pred):.2f}")
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# MAE : 3542.65
# MSE : 53630594.23
# r2 score : 0.61

# %%
# BEST SCORES

# %%
for degree in [2, 3, 4, 5]:
    poly = PolynomialFeatures(degree=degree, include_bias=False)
    X_train_poly = poly.fit_transform(X_train_scaled)
    X_test_poly = poly.transform(X_test_scaled)
    regression.fit(X_train_poly, y_train)
    y_pred = regression.predict(X_test_poly)
    print(f"Degree :{degree} , r2 score: {r2_score(y_test, y_pred):.2f}")
# Out:
# Degree :2 , r2 score: 0.82
# Degree :3 , r2 score: 0.82
# Degree :4 , r2 score: 0.72
# Degree :5 , r2 score: 0.38

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)
X_train_poly = poly.fit_transform(X_train_scaled)
X_test_poly = poly.transform(X_test_scaled)
regression.fit(X_train_poly, y_train)
y_pred = regression.predict(X_test_poly)

# %%
plt.figure(figsize=(6, 5))
plt.scatter(y_test, y_pred, alpha=0.5, color="r")
plt.xlabel("Test")
plt.ylabel("Prediction")
plt.title("Poly Regression")
plt.show()

# %%
param =\
{
    "n_neighbors": range(1, 11),
    "weights": ["uniform", "distance"],
    "metric": ["euclidean","manhattan"]
}

# %%
grid = GridSearchCV(KNeighborsRegressor(), param_grid=param, n_jobs=-1)
grid.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': range(1, 11),
#                          'weights': ['uniform', 'distance']})

# %%
y_pred = grid.predict(X_test_scaled)

# %%
grid.best_params_
# Out:
# {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}

# %%
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# r2 score : 0.79

# %%
plt.figure(figsize=(6, 5))
plt.scatter(y_test, y_pred, alpha=0.5, color="r")
plt.xlabel("Test")
plt.ylabel("Prediction")
plt.title("KNN GridSearch")
plt.show()

# %%
param = \
{
    "alpha": [0.001, 0.01, 0.1, 1, 10, 25, 50, 100]
}

# %%
grid = GridSearchCV(Lasso(), param_grid=param,cv=5,scoring="r2")
grid.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 25, 50, 100]},
#              scoring='r2')

# %%
y_pred = grid.predict(X_test_scaled)

# %%
grid.best_params_
# Out:
# {'alpha': 1}

# %%
print(f"r2 score : {r2_score(y_test, y_pred):.2f}")
# Out:
# r2 score : 0.71

# %%
plt.figure(figsize=(6, 5))
plt.scatter(y_test, y_pred, alpha=0.5, color="r")
plt.xlabel("Test")
plt.ylabel("Prediction")
plt.title("Lasso GridSearch")
plt.show()
